# %%
from ultralytics import YOLO
import os

# %% [markdown]
# # Descarga del Dataset para fine-tuning

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="5AYrTxoBH3CPVqYYShOX")
project = rf.workspace("workspace-5ujvu").project("basketball-players-fy4c2-vfsuv")
version = project.version(17)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Basketball-Players-17 to yolo26:: 100%|██████████| 23029/23029 [00:01<00:00, 16461.35it/s]
# Extracting Dataset Version Zip to Basketball-Players-17 in yolo26:: 100%|██████████| 652/652 [00:00<00:00, 1105.39it/s]

# %% [markdown]
# # Train Yolo model

# %%
model = YOLO("yolo26x.pt")

dataset_path = os.path.join(os.getcwd(), "Basketball-Players-17", "data.yaml")

# Entrenar
results = model.train(
    data=dataset_path,
    epochs=100,
    imgsz=640,
    plots=True,
    batch=4, # cambiar según la capacidad de tu GPU
    device=0
)
